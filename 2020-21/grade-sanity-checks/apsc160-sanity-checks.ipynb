# %%
import pandas as pd
import session_info

session_info.show()
# Out:
# <details>
# <summary>Click to view session information</summary>
# <pre>
# -----
# pandas              1.3.3
# session_info        1.0.0
# -----
# </pre>
# <details>
# <summary>Click to view modules imported as dependencies</summary>
# <pre>
# backcall                    0.2.0
# cython_runtime              NA
# dateutil                    2.8.2
# debugpy                     1.5.0
# decorator                   5.1.0
# entrypoints                 0.3
# ipykernel                   6.4.1
# ipython_genutils            0.2.0
# jedi                        0.17.2
# jupyter_server              1.13.4
# numpy                       1.22.1
# packaging                   21.0
# parso                       0.7.1
# pexpect                     4.8.0
# pickleshare                 0.7.5
# pkg_resources               NA
# prompt_toolkit              3.0.20
# ptyprocess                  0.7.0
# pyarrow                     6.0.1
# pydev_ipython               NA
# pydevconsole                NA
# pydevd                      2.4.1
# pydevd_concurrency_analyser NA
# pydevd_file_utils           NA
# pydevd_plugins              NA
# pydevd_tracing              NA
# pygments                    2.10.0
# pytz                        2021.3
# setuptools                  60.5.0
# six                         1.16.0
# sphinxcontrib               NA
# storemagic                  NA
# tornado                     6.1
# traitlets                   5.1.0
# wcwidth                     0.2.5
# zmq                         22.3.0
# </pre>
# </details> <!-- seems like this ends pre, so might as well be explicit -->
# <pre>
# -----
# IPython             7.28.0
# jupyter_client      7.0.6
# jupyter_core        4.8.1
# jupyterlab          3.2.8
# notebook            6.4.4
# -----
# Python 3.9.10 | packaged by conda-forge | (main, Jan 28 2022, 19:24:42) [GCC 9.4.0]
# Linux-5.15.15-76051515-generic-x86_64-with-glibc2.34
# -----
# Session information updated at 2022-02-10 12:07
# </pre>
# </details>

# %% [markdown]
# ## Read in data
#
# ### MS Teams spreadsheet grades

# %%
spreadsheet = pd.read_csv(
    # 'data/apsc160-2021w1-grades-2022edition.csv'
    'data/apsc160-2021w1-grades-feb09.csv'
).rename(
    columns = lambda x: x.lower()
).rename(
    columns={'snum': 'student_number'}
).assign(
    name=lambda df: df['pref'] + ' ' + df['last'],
).sort_values(
    'name'
)[['student_number', 'cwl', 'name']]#, 'Name_first']]
spreadsheet
# Out:
#      student_number       cwl             name
# 6          63728547  akanagal  Aakash Kanagala
# 321        82779430       aal        Aaron Lee
# 323        37388220  aarony03        Aaron Luo
# 319        47241583       NaN         Aaron Wu
# 0          22082580   aaryan6     Aaryan Patel
# ..              ...       ...              ...
# 318        37538964     znj03   Zeena Jarallah
# 371        50333350       bwz         Zhe Wang
# 591        15740723    zoescy           Zoe So
# 592        99569139   zoeyuen         Zoe Yuen
# 393        97847636    dawn57        Zoey Zhao
#
# [594 rows x 3 columns]

# %% [markdown]
# ### PrairieLearn
#
# File downloaded via `Gradebook -> Download`.

# %%
pl = pd.read_csv(
    'data/2022-01-25T1032_Grades-APSC_160_2021W1.csv'
).drop(
    index=[0,1]  # empty rows
).rename(
    columns = lambda x: x.lower()
).rename(
    columns={'sis user id': 'student_number'}
).assign(
    name=lambda df: df['student'].str.split(', ').apply(reversed).str.join(' '),
).query(
    'name != "Test student"'
).sort_values(
    'name'
)[['student_number', 'name']]
pl
# Out:
#      student_number             name
# 226      63728547.0  Aakash Kanagala
# 273      82779430.0        Aaron Lee
# 307      37388220.0        Aaron Luo
# 553      47241583.0         Aaron Wu
# 376      22082580.0     Aaryan Patel
# ..              ...              ...
# 216      37538964.0   Zeena Jarallah
# 538      50333350.0         Zhe Wang
# 463      15740723.0           Zoe So
# 587      99569139.0         Zoe Yuen
# 592      97847636.0        Zoey Zhao
#
# [594 rows x 2 columns]

# %% [markdown]
# ### Canvas
#
# File downloaded via `Grades -> Actions -> Export`.

# %%
canvas = pd.read_csv(
    'data/APSC_160_2021W1_gradebook.csv'
).rename(
    columns = lambda x: x.lower()
).query(
    'role == "Student"'
).assign(
    cwl=lambda df: df['uid'].str.split('@', expand=True)[0]
).sort_values(
    'name'
)[['cwl', 'name']]
canvas
# Out:
#           cwl                    name
# 21   akanagal         Aakash Kanagala
# 2         aal               Aaron Lee
# 3    aarony03               Aaron Luo
# 4     aaryan6            Aaryan Patel
# 15    afaouri  Abdel-Rahman AL-Faouri
# ..        ...                     ...
# 110       bwz                Zhe Wang
# 645  zoesimms             Zoe Simmons
# 644    zoescy                  Zoe So
# 646   zoeyuen                Zoe Yuen
# 158    dawn57               Zoey Zhao
#
# [647 rows x 2 columns]

# %% [markdown]
# ## Mismatched student names between the spreadsheet and PL

# %%
spreadsheet_pl = spreadsheet.merge(
    pl,
    on='name',
    how='outer',
    indicator=True,
    suffixes=('__spreadsheet', '__pl')
)
spreadsheet_pl[spreadsheet_pl.isna().any(axis=1)]
# Out:
#      student_number__spreadsheet       cwl                     name  \
# 3                     47241583.0       NaN                 Aaron Wu
# 9                     38643375.0       NaN              Adham Ahmed
# 83                    56711658.0   ben9354                Ben Chung
# 337                   41689902.0  vks28903            Kiara Suyanto
# 369                   79800975.0  lucaspri             Lucas Rimini
# 416                   33752544.0   elhan31     Mohammad Elhan Iqbal
# 448                   65584427.0  pauglz03        Paulina GonzÃ¡lez
# 586                   74579665.0      zakv          Zachary Varieur
# 594                          NaN       NaN           Benjamin Chung
# 595                          NaN       NaN              Elhan Iqbal
# 596                          NaN       NaN       Lucas Pavel Rimini
# 597                          NaN       NaN         Paulina González
# 598                          NaN       NaN  Vincentia Kiara Suyanto
# 599                          NaN       NaN              Zak Varieur
#
#      student_number__pl      _merge
# 3            47241583.0        both
# 9            38643375.0        both
# 83                  NaN   left_only
# 337                 NaN   left_only
# 369                 NaN   left_only
# 416                 NaN   left_only
# 448                 NaN   left_only
# 586                 NaN   left_only
# 594          56711658.0  right_only
# 595          33752544.0  right_only
# 596          79800975.0  right_only
# 597          65584427.0  right_only
# 598          41689902.0  right_only
# 599          74579665.0  right_only

# %% [markdown]
# All mismatches are seemingly due to different spelling of the same student names.
#
# ### Fix the mismatched student names and merge again

# %%
pl = pl.assign(
    name=lambda df: df['name'].replace({
        'Benjamin Chung': 'Ben Chung',
        'Elhan Iqbal': 'Mohammad Elhan Iqbal',
        'Lucas Pavel Rimini': 'Lucas Rimini',
        'Paulina González': 'Paulina GonzÃ¡lez',
        'Vincentia Kiara Suyanto': 'Kiara Suyanto',
        'Zak Varieur': 'Zachary Varieur'
    })
)

spreadsheet_pl = spreadsheet.merge(
    pl,
    on='name',
    how='outer',
    indicator=True,
    suffixes=('__spreadsheet', '__pl')
)
spreadsheet_pl[spreadsheet_pl.isna().any(axis=1)]
# Out:
#    student_number__spreadsheet  cwl         name  student_number__pl _merge
# 3                     47241583  NaN     Aaron Wu          47241583.0   both
# 9                     38643375  NaN  Adham Ahmed          38643375.0   both

# %% [markdown]
# We looked into these two students and they do not have any scores on PL,
# so it is fine that they are missing CWLs.
#
# ## Mismatched student names between the combined spreadsheet/PL frame and Canvas

# %%
spreadsheet_pl_canvas = spreadsheet_pl.drop(
    columns='_merge'  # since we are now recreating this column
).merge(
    canvas,
    on='name',
    how='outer',
    indicator=True,
    suffixes=('__spreadsheet', '__canvas')
)
spreadsheet_pl_canvas[spreadsheet_pl_canvas.isna().any(axis=1)]
# Out:
#      student_number__spreadsheet cwl__spreadsheet                   name  \
# 3                     47241583.0              NaN               Aaron Wu
# 9                     38643375.0              NaN            Adham Ahmed
# 570                   51608354.0         ychahbaz           Yara Chahbaz
# 594                          NaN              NaN              Ada Hmoud
# 595                          NaN              NaN        Aldiyar Mukatay
# 596                          NaN              NaN     Alexandre Jennison
# 597                          NaN              NaN        Allya Wellyanto
# 598                          NaN              NaN         Amelia Savazzi
# 599                          NaN              NaN             Amr Sherif
# 600                          NaN              NaN     Aren Dexter-Nickel
# 601                          NaN              NaN               Aria Mak
# 602                          NaN              NaN         Arvin Hosseini
# 603                          NaN              NaN         Brooklyn Keith
# 604                          NaN              NaN            Bryan Zhang
# 605                          NaN              NaN              Cate Ries
# 606                          NaN              NaN            Chantel Guo
# 607                          NaN              NaN     Chirath Attanayake
# 608                          NaN              NaN             Dylan Love
# 609                          NaN              NaN             Evan Smith
# 610                          NaN              NaN        Ezekiel Camacho
# 611                          NaN              NaN           Gordan Bozic
# 612                          NaN              NaN         Guanxiong Chen
# 613                          NaN              NaN            Halima Elmi
# 614                          NaN              NaN          Harman Aulakh
# 615                          NaN              NaN        JANAVI SINGH XX
# 616                          NaN              NaN      Jaden I-Hwang Mah
# 617                          NaN              NaN            Jessica Chu
# 618                          NaN              NaN            Jiashuo Liu
# 619                          NaN              NaN  Joanna Robinson-Leith
# 620                          NaN              NaN             Jordan Lee
# 621                          NaN              NaN        Kaemon Robinson
# 622                          NaN              NaN           Kate Barrett
# 623                          NaN              NaN          Keefee Rahman
# 624                          NaN              NaN       Kiana Jahanshahi
# 625                          NaN              NaN            Kira Zulauf
# 626                          NaN              NaN          Macco Dewdney
# 627                          NaN              NaN          Marcus Athans
# 628                          NaN              NaN              Mark John
# 629                          NaN              NaN                 Mio Li
# 630                          NaN              NaN             Morris Tai
# 631                          NaN              NaN       Natalie Bejerman
# 632                          NaN              NaN           Nicola Smith
# 633                          NaN              NaN         Nicolas Bednar
# 634                          NaN              NaN          Nicole Gammie
# 635                          NaN              NaN          Noah Zeibdawi
# 636                          NaN              NaN            Nora Kotkas
# 637                          NaN              NaN             Owen Pinto
# 638                          NaN              NaN             Sean Liang
# 639                          NaN              NaN              Sibo Wang
# 640                          NaN              NaN      Siham Abdelhameed
# 641                          NaN              NaN      Solenne Le Billon
# 642                          NaN              NaN    Sophia Katramadakis
# 643                          NaN              NaN           Sophie Perry
# 644                          NaN              NaN       Surya Koppisetti
# 645                          NaN              NaN          Tianchen Yuan
# 646                          NaN              NaN         Unund Boldkhuu
# 647                          NaN              NaN     Victoria Spenceley
# 648                          NaN              NaN        Wyatt Van Horne
# 649                          NaN              NaN            Zoe Simmons
#
#      student_number__pl cwl__canvas      _merge
# 3            47241583.0         NaN   left_only
# 9            38643375.0         NaN   left_only
# 570          51608354.0         NaN   left_only
# 594                 NaN      fhmoud  right_only
# 595                 NaN    amukatay  right_only
# 596                 NaN       ajenn  right_only
# 597                 NaN    allwelly  right_only
# 598                 NaN    asavazzi  right_only
# 599                 NaN     amr2021  right_only
# 600                 NaN         adn  right_only
# 601                 NaN     ariam03  right_only
# 602                 NaN    arvinhos  right_only
# 603                 NaN    blskeith  right_only
# 604                 NaN       byz16  right_only
# 605                 NaN    cateries  right_only
# 606                 NaN       cjg14  right_only
# 607                 NaN    chirath3  right_only
# 608                 NaN     dlove02  right_only
# 609                 NaN     evsmi24  right_only
# 610                 NaN     kiel330  right_only
# 611                 NaN     gjbozic  right_only
# 612                 NaN      gxchen  right_only
# 613                 NaN     helmi01  right_only
# 614                 NaN    haulakh9  right_only
# 615                 NaN    janaviis  right_only
# 616                 NaN     jaden12  right_only
# 617                 NaN      jchu03  right_only
# 618                 NaN     roman02  right_only
# 619                 NaN      jrob15  right_only
# 620                 NaN     jsc2003  right_only
# 621                 NaN    kaemon24  right_only
# 622                 NaN      kateb8  right_only
# 623                 NaN    rkaisaan  right_only
# 624                 NaN    kianajhn  right_only
# 625                 NaN     kzulauf  right_only
# 626                 NaN    machayla  right_only
# 627                 NaN     marcski  right_only
# 628                 NaN    markjohn  right_only
# 629                 NaN    censhang  right_only
# 630                 NaN      mdseqh  right_only
# 631                 NaN    bejerman  right_only
# 632                 NaN    nic0la10  right_only
# 633                 NaN     nbednar  right_only
# 634                 NaN    nmgammie  right_only
# 635                 NaN    nzeibdaw  right_only
# 636                 NaN     nkotkas  right_only
# 637                 NaN      opinto  right_only
# 638                 NaN    jingxin1  right_only
# 639                 NaN       sibow  right_only
# 640                 NaN     siham20  right_only
# 641                 NaN     slb4148  right_only
# 642                 NaN    skatrama  right_only
# 643                 NaN    sperry07  right_only
# 644                 NaN    suryaknr  right_only
# 645                 NaN    yuantc20  right_only
# 646                 NaN    unundb04  right_only
# 647                 NaN     vicspen  right_only
# 648                 NaN     wyattvh  right_only
# 649                 NaN    zoesimms  right_only

# %% [markdown]
# I looked into the student Yara Chahbaz who has a CWL in the spreadsheet but not on Canvas,
# and they don't have any scores on PL,
# so I don't think we need to worry about them.
# All the other students appear on Canvas but not on PL,
# which I believe means that they have dropped the course at some point
# so I am dropping them in the next cell.

# %%
spreadsheet_pl_canvas = spreadsheet_pl_canvas.query('_merge != "right_only"')

# %% [markdown]
# ## Differences between student numbers in the spreadsheet and on PL

# %%
spreadsheet_pl_canvas[spreadsheet_pl_canvas['student_number__spreadsheet'] != spreadsheet_pl_canvas['student_number__pl']]
# Out:
# Empty DataFrame
# Columns: [student_number__spreadsheet, cwl__spreadsheet, name, student_number__pl, cwl__canvas, _merge]
# Index: []

# %% [markdown]
# All students have the same student numbers in the spreadsheet as they do on PL.
#
# ## Differences between CWLs in the spreadsheet and on Canvas

# %%
spreadsheet_pl_canvas[spreadsheet_pl_canvas['cwl__spreadsheet'] != spreadsheet_pl_canvas['cwl__canvas']]
# Out:
#      student_number__spreadsheet cwl__spreadsheet              name  \
# 3                     47241583.0              NaN          Aaron Wu
# 9                     38643375.0              NaN       Adham Ahmed
# 541                   96454657.0            tilsu  Til Schmitt-Ulms
# 570                   51608354.0         ychahbaz      Yara Chahbaz
#
#      student_number__pl cwl__canvas     _merge
# 3            47241583.0         NaN  left_only
# 9            38643375.0         NaN  left_only
# 541          96454657.0    tilsu262       both
# 570          51608354.0         NaN  left_only

# %% [markdown]
# There is one student "Til Schmitt-Ulms"
# who has a different CWL in the spreadsheet (`tilsu`)
# compared to on Canvas (`tilsu262`).
# We should double check so that this student's grade is still uploaded correctly
# to the FSC.
